# %% [markdown]
# # 1. Simple Statistics and NLTK
#
# The following exercises use a portion of the Gutenberg corpus that is stored in the corpus dataset of NLTK. [The Project Gutenberg](http://www.gutenberg.org/) is a large collection of electronic books that are out of copyright. These books are free to download for reading, or for our case, for doing a little of corpus analysis.
#
# To obtain the list of files of NLTK's Gutenberg corpus, type the following commands:

# %%
import nltk
nltk.download('gutenberg')
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\61431\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\gutenberg.zip.
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# To obtain all words in the entire Gutenberg corpus of NLTK, type the following:

# %%
gutenbergwords = nltk.corpus.gutenberg.words()

# %% [markdown]
# Now you can find the total number of words, and the first 10 words (do not attempt to display all the words or your computer will freeze!):

# %%
len(gutenbergwords)
# Out:
# 2621613

# %%
gutenbergwords[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %% [markdown]
# You can also find the words of just a selection of documents, as shown below. For more details of what information you can extract from this corpus, read the "Gutenberg corpus" section of the [NLTK book chapter 2](http://www.nltk.org/book_1ed/ch02.html), section 2.1.

# %% [markdown]
# ### Exercise 1.1
# *Write Python code that prints the 10 most common words in each of the documents of the Gutenberg corpus. Can you identify any similarities among them?*

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
import collections

emma_count = collections.Counter(emma)
emma_count.most_common(10)
# Out:
# [(',', 11454),
#  ('.', 6928),
#  ('to', 5183),
#  ('the', 4844),
#  ('and', 4672),
#  ('of', 4279),
#  ('I', 3178),
#  ('a', 3004),
#  ('was', 2385),
#  ('her', 2381)]

# %% [markdown]
# We can see that the list of most common words is very similar in all documents, and they are all words that do not have much meaning, or they are not words at all but punctuation marks.

# %% [markdown]
# ### Exercise 1.2
# *Find the words with length of more than 7 characters in the complete Gutenberg corpus.*

# %%
#wordset = set(gutenbergwords)

words = [w for w in gutenbergwords if len(w) > 7]

words
# Out:
# ['Woodhouse',
#  'handsome',
#  'comfortable',
#  'disposition',
#  'blessings',
#  'existence',
#  'distress',
#  'youngest',
#  'daughters',
#  'affectionate',
#  'indulgent',
#  'consequence',
#  'marriage',
#  'mistress',
#  'indistinct',
#  'remembrance',
#  'caresses',
#  'supplied',
#  'excellent',
#  'governess',
#  'affection',
#  'Woodhouse',
#  'governess',
#  'daughters',
#  'particularly',
#  'intimacy',
#  'governess',
#  'mildness',
#  'restraint',
#  'authority',
#  'together',
#  'mutually',
#  'attached',
#  'esteeming',
#  'judgment',
#  'directed',
#  'situation',
#  'disposition',
#  'disadvantages',
#  'threatened',
#  'enjoyments',
#  'unperceived',
#  'misfortunes',
#  'disagreeable',
#  'consciousness',
#  'mournful',
#  'continuance',
#  'together',
#  'prospect',
#  'composed',
#  'happiness',
#  'unexceptionable',
#  'character',
#  'suitable',
#  'pleasant',
#  'satisfaction',
#  'considering',
#  'generous',
#  'friendship',
#  'promoted',
#  'recalled',
#  'kindness',
#  'kindness',
#  'affection',
#  'illnesses',
#  'childhood',
#  'gratitude',
#  'intercourse',
#  'unreserve',
#  'followed',
#  'Isabella',
#  'marriage',
#  'tenderer',
#  'recollection',
#  'companion',
#  'possessed',
#  'intelligent',
#  'informed',
#  'interested',
#  'concerns',
#  'peculiarly',
#  'interested',
#  'pleasure',
#  'affection',
#  'difference',
#  'advantages',
#  'domestic',
#  'suffering',
#  'intellectual',
#  'solitude',
#  'companion',
#  'conversation',
#  'rational',
#  'disparity',
#  'Woodhouse',
#  'increased',
#  'constitution',
#  'valetudinarian',
#  'activity',
#  'everywhere',
#  'friendliness',
#  'recommended',
#  'comparatively',
#  'matrimony',
#  'November',
#  'struggled',
#  'Hartfield',
#  'Christmas',
#  'Isabella',
#  'children',
#  'pleasant',
#  'Highbury',
#  'populous',
#  'amounting',
#  'Hartfield',
#  'separate',
#  'shrubberies',
#  'afforded',
#  'Woodhouses',
#  'consequence',
#  'acquaintance',
#  'universally',
#  'accepted',
#  'melancholy',
#  'impossible',
#  'necessary',
#  'cheerful',
#  'required',
#  'depressed',
#  'Matrimony',
#  'disagreeable',
#  'reconciled',
#  'daughter',
#  'marrying',
#  'compassion',
#  'entirely',
#  'affection',
#  'selfishness',
#  'differently',
#  'disposed',
#  'Hartfield',
#  'cheerfully',
#  'thoughts',
#  'impossible',
#  'humoured',
#  'pleasant',
#  'excellent',
#  'thoroughly',
#  'deserves',
#  'advantage',
#  'Randalls',
#  'distance',
#  'carriage',
#  'carriage',
#  'Randalls',
#  'daughter',
#  'housemaid',
#  'anywhere',
#  'mentioned',
#  'slighted',
#  'Whenever',
#  'curtseys',
#  'needlework',
#  'excellent',
#  'somebody',
#  'Whenever',
#  'daughter',
#  'exertions',
#  'maintain',
#  'backgammon',
#  'tolerably',
#  'attacked',
#  'backgammon',
#  'immediately',
#  'afterwards',
#  'unnecessary',
#  'Knightley',
#  'sensible',
#  'intimate',
#  'particularly',
#  'connected',
#  'Isabella',
#  'Highbury',
#  'frequent',
#  'directly',
#  'connexions',
#  'returned',
#  'Hartfield',
#  'Brunswick',
#  'circumstance',
#  'animated',
#  'Woodhouse',
#  'Knightley',
#  'cheerful',
#  'inquiries',
#  'Isabella',
#  'children',
#  'answered',
#  'satisfactorily',
#  'Woodhouse',
#  'gratefully',
#  'observed',
#  'Knightley',
#  'shocking',
#  'beautiful',
#  'moonlight',
#  'surprising',
#  'dreadfully',
#  'breakfast',
#  'congratulations',
#  'tolerably',
#  'business',
#  'Woodhouse',
#  'possibly',
#  'question',
#  'dependence',
#  'independence',
#  'Especially',
#  'fanciful',
#  'troublesome',
#  'creature',
#  'playfully',
#  'certainly',
#  'Woodhouse',
#  'sometimes',
#  'fanciful',
#  'troublesome',
#  'Knightley',
#  'horrible',
#  'Knightley',
#  'Knightley',
#  'Woodhouse',
#  'particularly',
#  'agreeable',
#  'circumstance',
#  'Knightley',
#  'reflection',
#  'charmingly',
#  'punctual',
#  'Knightley',
#  'impossible',
#  'companion',
#  'Knightley',
#  'marriage',
#  'advantage',
#  'acceptable',
#  'important',
#  'comfortable',
#  'provision',
#  'therefore',
#  'pleasure',
#  'forgotten',
#  'considerable',
#  'Knightley',
#  'foretell',
#  'whatever',
#  'greatest',
#  'amusement',
#  'perfectly',
#  'comfortable',
#  'constantly',
#  'occupied',
#  'business',
#  'acceptable',
#  'wherever',
#  'cheerful',
#  'certainly',
#  'deathbed',
#  'nonsense',
#  'believed',
#  'Broadway',
#  'gallantry',
#  'borrowed',
#  'umbrellas',
#  'Mitchell',
#  'instance',
#  'understand',
#  'Knightley',
#  'supposes',
#  'endeavour',
#  'properly',
#  'delicately',
#  'endeavouring',
#  'marriage',
#  'employment',
#  'planning',
#  'yourself',
#  'yourself',
#  'afterwards',
#  'pleasure',
#  'cleverer',
#  'entirely',
#  'pictures',
#  'something',
#  'promoted',
#  'encouragements',
#  'smoothed',
#  'Hartfield',
#  'comprehend',
#  'straightforward',
#  'rational',
#  'unaffected',
#  'concerns',
#  'yourself',
#  'interference',
#  'rejoined',
#  'Woodhouse',
#  'understanding',
#  'grievously',
#  'Highbury',
#  'deserves',
#  'comfortably',
#  'attention',
#  'Knightley',
#  'pleasure',
#  'Knightley',
#  'laughing',
#  'entirely',
#  'Highbury',
#  'respectable',
#  'generations',
#  'gentility',
#  'property',
#  'received',
#  'education',
#  'succeeding',
#  'independence',
#  'indisposed',
#  'pursuits',
#  'brothers',
#  'satisfied',
#  'cheerful',
#  'entering',
#  'embodied',
#  'favourite',
#  'military',
#  'introduced',
#  'Churchill',
#  'Yorkshire',
#  'Churchill',
#  'surprized',
#  'importance',
#  'connexion',
#  'Churchill',
#  'proportion',
#  'dissuaded',
#  'marriage',
#  'infinite',
#  'mortification',
#  'Churchill',
#  'unsuitable',
#  'connexion',
#  'happiness',
#  'goodness',
#  'resolution',
#  'unreasonable',
#  'unreasonable',
#  'luxuries',
#  'comparison',
#  'Enscombe',
#  'Churchill',
#  'Enscombe',
#  'considered',
#  'especially',
#  'Churchills',
#  'marriage',
#  'maintain',
#  'relieved',
#  'additional',
#  'softening',
#  'lingering',
#  'reconciliation',
#  'Churchill',
#  'children',
#  'creature',
#  'scruples',
#  'reluctance',
#  'supposed',
#  'overcome',
#  'considerations',
#  'Churchills',
#  'situation',
#  'complete',
#  'desirable',
#  'brothers',
#  'established',
#  'afforded',
#  'favourable',
#  'employment',
#  'Highbury',
#  'occupation',
#  'pleasures',
#  'eighteen',
#  'cheerfully',
#  'realised',
#  'competence',
#  'purchase',
#  'adjoining',
#  'Highbury',
#  'portionless',
#  'according',
#  'friendly',
#  'disposition',
#  'influence',
#  'tyrannic',
#  'influence',
#  'determination',
#  'settling',
#  'purchase',
#  'Randalls',
#  'Randalls',
#  'steadily',
#  'accomplished',
#  'obtained',
#  'beginning',
#  'existence',
#  'probability',
#  'happiness',
#  'marriage',
#  'delightful',
#  'pleasantest',
#  'gratitude',
#  'adoption',
#  'Churchill',
#  'unlikely',
#  'therefore',
#  'assistance',
#  'apprehension',
#  'capricious',
#  'governed',
#  'entirely',
#  'believed',
#  'deservedly',
#  'Highbury',
#  'sufficiently',
#  'belonging',
#  'prospects',
#  'Churchill',
#  'Highbury',
#  'curiosity',
#  'prevailed',
#  'compliment',
#  'returned',
#  'achieved',
#  'marriage',
#  'generally',
#  'proposed',
#  'attention',
#  'dissentient',
#  'returned',
#  'Churchill',
#  'strengthened',
#  'understood',
#  'occasion',
#  'Highbury',
#  'included',
#  'handsome',
#  'received',
#  'handsome',
#  'Churchill',
#  'understand',
#  'handsome',
#  'Woodhouse',
#  'Woodhouse',
#  'handsome',
#  'favourable',
#  'pleasing',
#  'attention',
#  'irresistible',
#  'addition',
#  'expression',
#  'congratulation',
#  'marriage',
#  'fortunate',
#  'fortunate',
#  'separation',
#  'friendship',
#  'pleasure',
#  'suffering',
#  'companionableness',
#  'character',
#  'situation',
#  'difficulties',
#  'privations',
#  'distance',
#  'Randalls',
#  'Hartfield',
#  'convenient',
#  'solitary',
#  'disposition',
#  'circumstances',
#  'approaching',
#  'hindrance',
#  'spending',
#  'evenings',
#  'together',
#  'situation',
#  'altogether',
#  'gratitude',
#  'satisfaction',
#  'satisfaction',
#  'cheerful',
#  'enjoyment',
#  'apparent',
#  'sometimes',
#  'surprize',
#  'Randalls',
#  'domestic',
#  'attended',
#  'pleasant',
#  'carriage',
#  'Woodhouse',
#  'recovering',
#  'likelihood',
#  'alleviation',
#  'Woodhouse',
#  'compliments',
#  'neighbours',
#  'sorrowful',
#  'distress',
#  'different',
#  'unwholesome',
#  'regarded',
#  'therefore',
#  'earnestly',
#  'dissuade',
#  'earnestly',
#  'consulting',
#  'apothecary',
#  'intelligent',
#  'gentlemanlike',
#  'frequent',
#  'comforts',
#  'Woodhouse',
#  'acknowledge',
#  'inclination',
#  'certainly',
#  'disagree',
#  'moderately',
#  'confirmation',
#  'Woodhouse',
#  'influence',
#  'benevolent',
#  'Highbury',
#  'Woodhouse',
#  'Woodhouse',
#  'residence',
#  'Hartfield',
#  'daughter',
#  'intercourse',
#  'families',
#  'acquaintance',
#  'Fortunately',
#  'Highbury',
#  'including',
#  'Randalls',
#  'adjoining',
#  'Knightley',
#  'comprehended',
#  'unfrequently',
#  'persuasion',
#  'preferred',
#  'scarcely',
#  'standing',
#  'Knightley',
#  'privilege',
#  'exchanging',
#  'solitude',
#  'elegancies',
#  'Woodhouse',
#  'daughter',
#  'invitation',
#  'Hartfield',
#  'Woodhouse',
#  'hardship',
#  'grievance',
#  'Highbury',
#  'quadrille',
#  'daughter',
#  'considered',
#  'harmless',
#  'untoward',
#  'circumstances',
#  'daughter',
#  'uncommon',
#  'popularity',
#  'handsome',
#  'predicament',
#  'intellectual',
#  'superiority',
#  'atonement',
#  'frighten',
#  'cleverness',
#  'distinction',
#  'endeavour',
#  'possible',
#  'universal',
#  'contented',
#  'interested',
#  'happiness',
#  'quicksighted',
#  'fortunate',
#  'creature',
#  'surrounded',
#  'blessings',
#  'excellent',
#  'neighbours',
#  'simplicity',
#  'cheerfulness',
#  'contented',
#  'grateful',
#  'recommendation',
#  'felicity',
#  'Woodhouse',
#  'communications',
#  'harmless',
#  'mistress',
#  'seminary',
#  'establishment',
#  'professed',
#  'sentences',
#  'nonsense',
#  'acquirements',
#  'morality',
#  'principles',
#  'enormous',
#  'fashioned',
#  'Boarding',
#  'reasonable',
#  'quantity',
#  'accomplishments',
#  'reasonable',
#  'scramble',
#  'themselves',
#  'education',
#  'prodigies',
#  'deservedly',
#  'Highbury',
#  'reckoned',
#  'particularly',
#  'children',
#  'wholesome',
#  'chilblains',
#  'motherly',
#  'entitled',
#  'occasional',
#  'formerly',
#  'Woodhouse',
#  'kindness',
#  'particular',
#  'whenever',
#  'sixpences',
#  'fireside',
#  'frequently',
#  'concerned',
#  'delighted',
#  'comfortable',
#  'contriving',
#  'prosings',
#  'evenings',
#  'fearfully',
#  'anticipated',
#  'requesting',
#  'respectful',
#  'seventeen',
#  'interest',
#  'gracious',
#  'invitation',
#  'returned',
#  'mistress',
#  'daughter',
#  'somebody',
#  'Somebody',
#  'somebody',
#  'condition',
#  'generally',
#  'acquired',
#  'Highbury',
#  'returned',
#  'happened',
#  'particularly',
#  'features',
#  'sweetness',
#  'determined',
#  'continue',
#  'acquaintance',
#  'remarkably',
#  'conversation',
#  'altogether',
#  'engaging',
#  'inconveniently',
#  'unwilling',
#  'becoming',
#  'deference',
#  'pleasantly',
#  'grateful',
#  'admitted',
#  'Hartfield',
#  'artlessly',
#  'impressed',
#  'appearance',
#  'superior',
#  'encouragement',
#  'Encouragement',
#  'inferior',
#  'Highbury',
#  'connexions',
#  'acquaintance',
#  'unworthy',
#  'character',
#  'Knightley',
#  'residing',
#  'creditably',
#  'believed',
#  'Knightley',
#  'unpolished',
#  'intimates',
#  'knowledge',
#  'elegance',
#  'acquaintance',
#  'introduce',
#  'opinions',
#  'interesting',
#  'certainly',
#  'undertaking',
#  'becoming',
#  'situation',
#  'admiring',
#  'listening',
#  'betweens',
#  'forwards',
#  'alacrity',
#  'indifferent',
#  'attentively',
#  'delighted',
#  'recommend',
#  'scalloped',
#  'acceptable',
#  'scruples',
#  'occasions',
#  'Woodhouses',
#  'feelings',
#  'conviction',
#  'unwholesome',
#  'hospitality',
#  'welcomed',
#  'visitors',
#  'thorough',
#  'approbation',
#  'recommend',
#  'constrain',
#  'comfortably',
#  'clearing',
#  'venturing',
#  'unwholesome',
#  'understands',
#  'recommend',
#  '_little_',
#  'unwholesome',
#  'preserves',
#  'disagree',
#  'supplied',
#  'visitors',
#  'satisfactory',
#  'particular',
#  'pleasure',
#  'happiness',
#  'intentions',
#  'Woodhouse',
#  'personage',
#  'Highbury',
#  'prospect',
#  'introduction',
#  'pleasure',
#  'grateful',
#  'gratified',
#  'feelings',
#  'delighted',
#  'affability',
#  'Woodhouse',
#  'actually',
#  'intimacy',
#  'Hartfield',
#  'inviting',
#  'encouraging',
#  'acquaintance',
#  'increased',
#  'satisfaction',
#  'companion',
#  'foreseen',
#  'important',
#  'shrubbery',
#  'divisions',
#  'sufficed',
#  'marriage',
#  'exercise',
#  'confined',
#  'ventured',
#  'Randalls',
#  'pleasant',
#  'therefore',
#  'valuable',
#  'addition',
#  'privileges',
#  'approved',
#  'confirmed',
#  'certainly',
#  'grateful',
#  'disposition',
#  'desiring',
#  'attachment',
#  'inclination',
#  'appreciating',
#  'strength',
#  'understanding',
#  'expected',
#  'Altogether',
#  'convinced',
#  'something',
#  'required',
#  'question',
#  'different',
#  'sentiment',
#  'distinct',
#  'independent',
#  'gratitude',
#  'attempts',
#  'usefulness',
#  'endeavour',
#  'questions',
#  'situation',
#  'discovered',
#  'penetration',
#  'satisfied',
#  'teachers',
#  'naturally',
#  'conversation',
#  'acquaintance',
#  'occupied',
#  'thoughts',
#  'pleasures',
#  'describe',
#  'comforts',
#  'encouraged',
#  'talkativeness',
#  'enjoying',
#  'youthful',
#  'simplicity',
#  'exultation',
#  'parlours',
#  'parlours',
#  'Alderneys',
#  'handsome',
#  'handsome',
#  'thinking',
#  'immediate',
#  'understand',
#  'feelings',
#  'fancying',
#  'daughter',
#  'together',
#  'appeared',
#  'narrative',
#  'mentioned',
#  'approbation',
#  'something',
#  'hospitality',
#  'kindness',
#  'required',
#  'inspiriting',
#  'questions',
#  'increased',
#  'particularly',
#  'evidently',
#  'moonlight',
#  'humoured',
#  'obliging',
#  'obliging',
#  'shepherd',
#  'believed',
#  'understood',
#  'believed',
#  'impossible',
#  'therefore',
#  'whenever',
#  '_wanted_',
#  'beautiful',
#  'teachers',
#  'Richardson',
#  'information',
#  'business',
#  'Agricultural',
#  'sometimes',
#  'something',
#  'Extracts',
#  'entertaining',
#  'Wakefield',
#  'Children',
#  'mentioned',
#  'determined',
#  'question',
#  'handsome',
#  'handsome',
#  'Highbury',
#  'Kingston',
#  'horseback',
#  'curiosity',
#  'yeomanry',
#  'precisely',
#  'creditable',
#  'appearance',
#  'interest',
#  'families',
#  'therefore',
#  'observed',
#  'respectable',
#  'birthday',
#  'fortnight',
#  'difference',
#  'perfectly',
#  'comfortable',
#  'probably',
#  'desirable',
#  'Woodhouse',
#  'independence',
#  'entirely',
#  'beforehand',
#  'Whatever',
#  'whatever',
#  'property',
#  'employed',
#  'diligence',
#  'impossible',
#  'realised',
#  'comfortably',
#  'whenever',
#  'acquainted',
#  'superior',
#  'education',
#  'altogether',
#  'objected',
#  'misfortune',
#  'particularly',
#  'associates',
#  'gentleman',
#  'daughter',
#  'pleasure',
#  'degrading',
#  'Hartfield',
#  'Woodhouse',
#  'understand',
#  'influence',
#  'established',
#  'independent',
#  'Hartfield',
#  'Woodhouse',
#  'permanently',
#  'connected',
#  'advisable',
#  'acquaintance',
#  'therefore',
#  'intimacy',
#  'acquainted',
#  'probably',
#  'daughter',
#  'education',
#  'education',
#  'acquaintance',
#  'especially',
#  'Elizabeth',
#  'educated',
#  'ignorant',
#  'certainly',
#  'fluctuations',
#  'alarming',
#  'symptoms',
#  'difficulty',
#  'friendly',
#  'arrangement',
#  'respectfully',
#  'unfeigned',
#  'satisfaction',
#  'companion',
#  'opportunity',
#  'together',
#  'sufficiently',
#  'acquainted',
#  'appearance',
#  'sensible',
#  'advantage',
#  'contrasted',
#  'gentlemen',
#  'inclination',
#  'insensible',
#  'voluntarily',
#  'gentleness',
#  'admiration',
#  'remained',
#  'together',
#  'Woodhouse',
#  ...]

# %% [markdown]
# ### Exercise 1.3
# *Find the words that are longer than 7 characters and occur more than 7 times in the complete Gutenberg corpus.*

# %%
wordsCount = collections.Counter(words)
{k:v for (k,v) in wordsCount.items() if v > 7}
# Out:
# {'Woodhouse': 313,
#  'handsome': 130,
#  'comfortable': 108,
#  'disposition': 73,
#  'blessings': 24,
#  'existence': 47,
#  'distress': 111,
#  'youngest': 42,
#  'daughters': 319,
#  'affectionate': 56,
#  'indulgent': 11,
#  'consequence': 132,
#  'marriage': 142,
#  'mistress': 137,
#  'remembrance': 90,
#  'supplied': 34,
#  'excellent': 164,
#  'governess': 17,
#  'affection': 163,
#  'particularly': 136,
#  'intimacy': 46,
#  'mildness': 16,
#  'restraint': 22,
#  'authority': 88,
#  'together': 958,
#  'mutually': 8,
#  'attached': 74,
#  'judgment': 373,
#  'directed': 33,
#  'situation': 169,
#  'threatened': 21,
#  'enjoyments': 10,
#  'disagreeable': 34,
#  'consciousness': 56,
#  'mournful': 12,
#  'continuance': 17,
#  'prospect': 58,
#  'composed': 36,
#  'happiness': 230,
#  'unexceptionable': 8,
#  'character': 213,
#  'suitable': 14,
#  'pleasant': 193,
#  'satisfaction': 106,
#  'considering': 80,
#  'generous': 58,
#  'friendship': 102,
#  'promoted': 12,
#  'recalled': 21,
#  'kindness': 167,
#  'childhood': 22,
#  'gratitude': 80,
#  'intercourse': 32,
#  'unreserve': 10,
#  'followed': 301,
#  'Isabella': 93,
#  'recollection': 48,
#  'companion': 139,
#  'possessed': 63,
#  'intelligent': 25,
#  'informed': 50,
#  'interested': 45,
#  'concerns': 29,
#  'peculiarly': 24,
#  'pleasure': 411,
#  'difference': 147,
#  'advantages': 37,
#  'domestic': 46,
#  'suffering': 80,
#  'intellectual': 38,
#  'solitude': 39,
#  'conversation': 186,
#  'rational': 45,
#  'disparity': 10,
#  'increased': 112,
#  'constitution': 13,
#  'activity': 27,
#  'everywhere': 48,
#  'friendliness': 11,
#  'recommended': 30,
#  'comparatively': 36,
#  'matrimony': 10,
#  'November': 21,
#  'struggled': 14,
#  'Hartfield': 160,
#  'Christmas': 53,
#  'children': 2223,
#  'Highbury': 125,
#  'populous': 19,
#  'separate': 105,
#  'afforded': 25,
#  'acquaintance': 217,
#  'universally': 15,
#  'accepted': 69,
#  'melancholy': 67,
#  'impossible': 164,
#  'necessary': 149,
#  'cheerful': 96,
#  'required': 78,
#  'depressed': 11,
#  'reconciled': 28,
#  'daughter': 552,
#  'marrying': 50,
#  'compassion': 87,
#  'entirely': 189,
#  'selfishness': 20,
#  'differently': 30,
#  'disposed': 84,
#  'cheerfully': 26,
#  'thoughts': 310,
#  'humoured': 35,
#  'thoroughly': 56,
#  'deserves': 22,
#  'advantage': 116,
#  'Randalls': 90,
#  'distance': 162,
#  'carriage': 192,
#  'anywhere': 71,
#  'mentioned': 105,
#  'slighted': 16,
#  'Whenever': 23,
#  'needlework': 10,
#  'somebody': 70,
#  'exertions': 19,
#  'maintain': 24,
#  'tolerably': 35,
#  'attacked': 13,
#  'immediately': 326,
#  'afterwards': 231,
#  'unnecessary': 36,
#  'Knightley': 389,
#  'sensible': 95,
#  'intimate': 40,
#  'connected': 52,
#  'frequent': 42,
#  'directly': 164,
#  'connexions': 18,
#  'returned': 408,
#  'Brunswick': 11,
#  'circumstance': 115,
#  'animated': 25,
#  'inquiries': 33,
#  'answered': 804,
#  'gratefully': 16,
#  'observed': 146,
#  'shocking': 32,
#  'beautiful': 253,
#  'moonlight': 36,
#  'surprising': 17,
#  'dreadfully': 25,
#  'breakfast': 126,
#  'congratulations': 9,
#  'business': 369,
#  'possibly': 91,
#  'question': 254,
#  'dependence': 24,
#  'independence': 27,
#  'fanciful': 14,
#  'troublesome': 21,
#  'creature': 182,
#  'certainly': 353,
#  'sometimes': 253,
#  'horrible': 70,
#  'agreeable': 120,
#  'reflection': 59,
#  'punctual': 10,
#  'acceptable': 39,
#  'important': 113,
#  'provision': 22,
#  'therefore': 1146,
#  'forgotten': 154,
#  'considerable': 98,
#  'whatever': 183,
#  'greatest': 147,
#  'amusement': 54,
#  'perfectly': 238,
#  'constantly': 38,
#  'occupied': 57,
#  'wherever': 49,
#  'nonsense': 57,
#  'believed': 246,
#  'Broadway': 10,
#  'gallantry': 22,
#  'borrowed': 18,
#  'instance': 66,
#  'understand': 415,
#  'endeavour': 27,
#  'properly': 56,
#  'delicately': 8,
#  'endeavouring': 19,
#  'employment': 37,
#  'planning': 8,
#  'yourself': 289,
#  'pictures': 40,
#  'something': 881,
#  'comprehend': 53,
#  'unaffected': 14,
#  'interference': 18,
#  'rejoined': 11,
#  'understanding': 239,
#  'grievously': 8,
#  'comfortably': 31,
#  'attention': 200,
#  'laughing': 144,
#  'respectable': 59,
#  'generations': 138,
#  'gentility': 9,
#  'property': 58,
#  'received': 364,
#  'education': 55,
#  'succeeding': 19,
#  'indisposed': 8,
#  'pursuits': 17,
#  'brothers': 60,
#  'satisfied': 194,
#  'entering': 84,
#  'favourite': 105,
#  'military': 29,
#  'introduced': 46,
#  'Churchill': 241,
#  'Yorkshire': 10,
#  'surprized': 33,
#  'importance': 68,
#  'connexion': 41,
#  'proportion': 29,
#  'infinite': 57,
#  'mortification': 22,
#  'goodness': 110,
#  'resolution': 84,
#  'unreasonable': 22,
#  'comparison': 48,
#  'Enscombe': 36,
#  'considered': 126,
#  'especially': 167,
#  'Churchills': 15,
#  'relieved': 29,
#  'additional': 29,
#  'lingering': 24,
#  'reconciliation': 20,
#  'scruples': 20,
#  'reluctance': 9,
#  'supposed': 139,
#  'overcome': 71,
#  'considerations': 10,
#  'complete': 114,
#  'desirable': 44,
#  'established': 106,
#  'favourable': 34,
#  'occupation': 23,
#  'pleasures': 40,
#  'eighteen': 45,
#  'realised': 11,
#  'purchase': 34,
#  'adjoining': 17,
#  'according': 817,
#  'friendly': 82,
#  'influence': 99,
#  'determination': 20,
#  'settling': 25,
#  'steadily': 69,
#  'accomplished': 52,
#  'obtained': 57,
#  'beginning': 275,
#  'probability': 39,
#  'delightful': 83,
#  'adoption': 9,
#  'unlikely': 10,
#  'assistance': 54,
#  'apprehension': 22,
#  'capricious': 11,
#  'governed': 17,
#  'sufficiently': 42,
#  'belonging': 38,
#  'prospects': 19,
#  'curiosity': 140,
#  'prevailed': 65,
#  'compliment': 48,
#  'achieved': 17,
#  'generally': 112,
#  'proposed': 39,
#  'strengthened': 47,
#  'understood': 153,
#  'occasion': 127,
#  'included': 25,
#  'pleasing': 70,
#  'irresistible': 23,
#  'addition': 32,
#  'expression': 83,
#  'fortunate': 37,
#  'separation': 47,
#  'difficulties': 57,
#  'convenient': 38,
#  'solitary': 60,
#  'circumstances': 129,
#  'approaching': 37,
#  'spending': 21,
#  'evenings': 17,
#  'altogether': 136,
#  'enjoyment': 64,
#  'apparent': 36,
#  'surprize': 38,
#  'attended': 52,
#  'recovering': 24,
#  'compliments': 38,
#  'neighbours': 83,
#  'sorrowful': 37,
#  'different': 217,
#  'regarded': 60,
#  'earnestly': 67,
#  'dissuade': 12,
#  'consulting': 12,
#  'apothecary': 15,
#  'gentlemanlike': 11,
#  'comforts': 24,
#  'acknowledge': 60,
#  'inclination': 59,
#  'confirmation': 11,
#  'benevolent': 28,
#  'residence': 22,
#  'families': 210,
#  'including': 23,
#  'comprehended': 13,
#  'persuasion': 40,
#  'preferred': 30,
#  'scarcely': 121,
#  'standing': 281,
#  'privilege': 21,
#  'invitation': 75,
#  'hardship': 10,
#  'harmless': 34,
#  'uncommon': 30,
#  'superiority': 33,
#  'atonement': 89,
#  'frighten': 14,
#  'distinction': 34,
#  'possible': 301,
#  'universal': 54,
#  'contented': 22,
#  'surrounded': 33,
#  'simplicity': 57,
#  'cheerfulness': 39,
#  'grateful': 59,
#  'recommendation': 18,
#  'felicity': 25,
#  'communications': 12,
#  'establishment': 19,
#  'professed': 20,
#  'sentences': 16,
#  'morality': 10,
#  'principles': 35,
#  'enormous': 68,
#  'fashioned': 52,
#  'reasonable': 66,
#  'quantity': 27,
#  'themselves': 776,
#  'reckoned': 31,
#  'wholesome': 19,
#  'entitled': 18,
#  'occasional': 27,
#  'formerly': 26,
#  'particular': 221,
#  'whenever': 89,
#  'fireside': 10,
#  'frequently': 52,
#  'concerned': 58,
#  'delighted': 110,
#  'anticipated': 14,
#  'respectful': 15,
#  'seventeen': 24,
#  'interest': 205,
#  'gracious': 64,
#  'Somebody': 10,
#  'condition': 51,
#  'acquired': 19,
#  'happened': 206,
#  'features': 53,
#  'sweetness': 33,
#  'determined': 173,
#  'continue': 81,
#  'remarkably': 30,
#  'engaging': 17,
#  'unwilling': 36,
#  'becoming': 37,
#  'deference': 8,
#  'pleasantly': 25,
#  'admitted': 45,
#  'impressed': 13,
#  'appearance': 170,
#  'superior': 120,
#  'encouragement': 36,
#  'inferior': 47,
#  'unworthy': 25,
#  'residing': 8,
#  'knowledge': 339,
#  'elegance': 45,
#  'introduce': 27,
#  'opinions': 54,
#  'interesting': 90,
#  'admiring': 17,
#  'listening': 70,
#  'forwards': 21,
#  'alacrity': 14,
#  'indifferent': 74,
#  'attentively': 18,
#  'recommend': 34,
#  'occasions': 28,
#  'feelings': 286,
#  'conviction': 50,
#  'hospitality': 22,
#  'welcomed': 8,
#  'visitors': 29,
#  'thorough': 25,
#  'approbation': 48,
#  'clearing': 22,
#  'understands': 11,
#  'satisfactory': 19,
#  'intentions': 24,
#  'introduction': 24,
#  'gratified': 21,
#  'actually': 89,
#  'inviting': 19,
#  'encouraging': 26,
#  'foreseen': 15,
#  'shrubbery': 8,
#  'divisions': 25,
#  'sufficed': 10,
#  'exercise': 49,
#  'confined': 34,
#  'ventured': 33,
#  'valuable': 44,
#  'approved': 27,
#  'confirmed': 31,
#  'desiring': 22,
#  'attachment': 111,
#  'strength': 376,
#  'expected': 166,
#  'convinced': 103,
#  'sentiment': 29,
#  'distinct': 39,
#  'independent': 31,
#  'attempts': 25,
#  'questions': 85,
#  'discovered': 79,
#  'penetration': 14,
#  'teachers': 22,
#  'naturally': 61,
#  'describe': 37,
#  'encouraged': 32,
#  'enjoying': 24,
#  'youthful': 20,
#  'exultation': 15,
#  'thinking': 230,
#  'immediate': 62,
#  'fancying': 22,
#  'appeared': 306,
#  'narrative': 12,
#  'evidently': 55,
#  'obliging': 57,
#  'shepherd': 57,
#  'information': 70,
#  'entertaining': 20,
#  'Children': 29,
#  'Kingston': 8,
#  'horseback': 22,
#  'precisely': 54,
#  'creditable': 8,
#  'birthday': 41,
#  'fortnight': 54,
#  'probably': 145,
#  'beforehand': 16,
#  'Whatever': 43,
#  'employed': 68,
#  'diligence': 13,
#  'acquainted': 110,
#  'objected': 8,
#  'misfortune': 29,
#  'associates': 15,
#  'gentleman': 311,
#  'advisable': 10,
#  'Elizabeth': 101,
#  'educated': 19,
#  'ignorant': 65,
#  'alarming': 16,
#  'symptoms': 17,
#  'difficulty': 95,
#  'arrangement': 34,
#  'respectfully': 12,
#  'unfeigned': 12,
#  'opportunity': 96,
#  'contrasted': 8,
#  'gentlemen': 162,
#  'insensible': 17,
#  'voluntarily': 15,
#  'gentleness': 23,
#  'admiration': 84,
#  'remained': 183,
#  'happening': 16,
#  'undoubtedly': 28,
#  'compared': 48,
#  'imagined': 58,
#  'mortified': 19,
#  'repeatedly': 19,
#  'specimens': 9,
#  'perceiving': 22,
#  'wondering': 52,
#  'Certainly': 54,
#  'carrying': 81,
#  'speaking': 242,
#  'disgusting': 8,
#  'awkwardness': 13,
#  'detestable': 12,
#  'solemnly': 25,
#  'completely': 100,
#  'appearances': 21,
#  'forgetting': 23,
#  'illiterate': 9,
#  'remember': 350,
#  'displeasure': 19,
#  'openness': 14,
#  'quickness': 12,
#  'downright': 18,
#  'commanding': 22,
#  'contrary': 86,
#  'softness': 11,
#  'repeated': 197,
#  'personal': 50,
#  'probable': 36,
#  'equalled': 9,
#  'doubtful': 45,
#  'sufficient': 77,
#  'vicarage': 9,
#  'deficiency': 12,
#  'meetings': 16,
#  'foundation': 71,
#  'fastidious': 10,
#  'conquered': 20,
#  'supplying': 8,
#  'yesterday': 121,
#  'agreeing': 9,
#  'associate': 8,
#  'objection': 49,
#  'inducement': 8,
#  'regularly': 31,
#  'arranged': 35,
#  'fourteen': 37,
#  'preserved': 40,
#  'expecting': 29,
#  'requiring': 9,
#  'industry': 22,
#  'patience': 99,
#  'subjection': 24,
#  'persuade': 53,
#  'feelingly': 8,
#  'dependent': 12,
#  'preparing': 32,
#  'receiving': 60,
#  'material': 54,
#  'vexation': 31,
#  'ignorance': 63,
#  'flattery': 20,
#  'presenting': 8,
#  'inferiority': 11,
#  'uncomfortable': 31,
#  'mistaken': 108,
#  'varieties': 12,
#  'brilliant': 26,
#  'countenance': 200,
#  'complexion': 39,
#  'personally': 20,
#  'confidence': 138,
#  'qualities': 26,
#  'frightened': 100,
#  'consider': 165,
#  'somewhat': 138,
#  'discussion': 17,
#  'supposing': 35,
#  'inconvenience': 29,
#  'apprehended': 9,
#  'province': 32,
#  'declares': 12,
#  'hereabouts': 11,
#  'creating': 11,
#  'respecting': 12,
#  'suspected': 42,
#  'transition': 10,
#  'direction': 82,
#  'decidedly': 30,
#  'hesitation': 27,
#  'following': 152,
#  'assurance': 38,
#  'confident': 26,
#  'perception': 8,
#  'striking': 57,
#  'improvement': 28,
#  'graceful': 24,
#  'attractions': 10,
#  'infinitely': 37,
#  'contradict': 18,
#  'decision': 38,
#  'principally': 13,
#  'animation': 21,
#  'likeness': 72,
#  'exclaimed': 165,
#  'exquisite': 38,
#  'possession': 164,
#  'attempted': 32,
#  'tolerable': 38,
#  'charming': 81,
#  'drawings': 26,
#  'inimitable': 10,
#  'raptures': 15,
#  'delicate': 67,
#  'difficult': 48,
#  'peculiarity': 9,
#  'answering': 54,
#  'persuaded': 102,
#  'proposal': 28,
#  'pressing': 21,
#  'produced': 84,
#  'containing': 30,
#  'portraits': 9,
#  'finished': 143,
#  'beginnings': 10,
#  'displayed': 14,
#  'progress': 35,
#  'steadiness': 14,
#  'approached': 31,
#  'excellence': 24,
#  'deceived': 69,
#  'musician': 8,
#  'reputation': 24,
#  'deserved': 46,
#  'spirited': 20,
#  'companions': 145,
#  'performances': 8,
#  'sleeping': 66,
#  'provoked': 51,
#  'flattering': 27,
#  'persuading': 15,
#  'husbands': 31,
#  'repeating': 29,
#  'declaration': 22,
#  'portrait': 24,
#  'destined': 20,
#  'honourable': 73,
#  'blushing': 11,
#  'attitude': 38,
#  'presented': 67,
#  'watching': 92,
#  'elsewhere': 36,
#  'occurred': 80,
#  'listened': 77,
#  'smallest': 83,
#  'intermission': 10,
#  'displeased': 47,
#  'complaisance': 11,
#  'considerably': 22,
#  'memorial': 34,
#  'associations': 11,
#  'promising': 19,
#  'entreated': 22,
#  'permission': 21,
#  'attending': 43,
#  'civilities': 18,
#  'accompanied': 34,
#  'continual': 84,
#  'defended': 10,
#  'suspecting': 17,
#  'addressing': 30,
#  'eyebrows': 24,
#  'resemblance': 31,
#  'Consider': 36,
#  'presents': 33,
#  'proportions': 12,
#  'shoulders': 103,
#  'admirable': 26,
#  'depended': 33,
#  'December': 14,
#  'stirring': 21,
#  'commission': 21,
#  'executing': 8,
#  'repetition': 17,
#  'entreaties': 21,
#  'assurances': 17,
#  'directions': 34,
#  'precious': 147,
#  'principal': 53,
#  'services': 19,
#  'agitated': 25,
#  'announcing': 20,
#  'extraordinary': 101,
#  'contained': 32,
#  'expectation': 73,
#  'composition': 9,
#  'language': 79,
#  'sentiments': 33,
#  'conveyed': 32,
#  'expressed': 68,
#  'liberality': 15,
#  'propriety': 34,
#  'delicacy': 41,
#  'anxiously': 35,
#  'strongly': 41,
#  'returning': 97,
#  'speedily': 35,
#  'intelligible': 19,
#  'expressions': 27,
#  'requires': 22,
#  'prompted': 11,
#  'disappointment': 50,
#  'continued': 313,
#  'apprehend': 11,
#  'bewitching': 8,
#  'powerful': 66,
#  'hesitate': 11,
#  'hesitating': 10,
#  'graciously': 10,
#  'definition': 10,
#  'confused': 39,
#  'thoughtfully': 22,
#  'mechanically': 15,
#  'impatience': 42,
#  'suspense': 33,
#  'approving': 9,
#  'wavering': 13,
#  'forcibly': 11,
#  'dreadful': 114,
#  'banished': 19,
#  'conceited': 12,
#  'conscience': 98,
#  'opposing': 15,
#  'visiting': 24,
#  'consideration': 56,
#  'consolation': 50,
#  'sentence': 62,
#  'tendency': 16,
#  'decisive': 13,
#  'ungrateful': 15,
#  'bringing': 91,
#  'conquest': 13,
#  'attentions': 48,
#  'Hitherto': 12,
#  'explained': 57,
#  'cheering': 11,
#  'rejected': 44,
#  'original': 62,
#  'allowing': 11,
#  'suspicious': 20,
#  'imaginations': 15,
#  'stronger': 89,
#  'gradually': 46,
#  'previously': 41,
#  'civility': 45,
#  'ceremony': 34,
#  'offering': 765,
#  'contrast': 35,
#  'apologies': 17,
#  'stranger': 239,
#  'substitute': 15,
#  'entertain': 18,
#  'likewise': 132,
#  'seemingly': 17,
#  'inclined': 65,
#  'voluntary': 17,
#  'improved': 34,
#  'intended': 65,
#  'Something': 55,
#  'tiresome': 12,
#  'contradiction': 18,
#  'presently': 90,
#  'desperately': 16,
#  'imprudent': 15,
#  'esteemed': 23,
#  'counsellor': 17,
#  'detained': 17,
#  'absolutely': 73,
#  'inferred': 8,
#  'indignation': 88,
#  'simpleton': 8,
#  'incomprehensible': 13,
#  'Nonsense': 12,
#  'relations': 34,
#  'experience': 49,
#  'tempered': 35,
#  'partiality': 22,
#  'statement': 19,
#  'estimated': 8,
#  'allowance': 19,
#  'ambition': 25,
#  'proceeded': 69,
#  'farthest': 19,
#  'assertion': 17,
#  'contemptible': 17,
#  'represent': 15,
#  'possesses': 9,
#  'recommendations': 8,
#  'certainty': 41,
#  'consequently': 23,
#  'comprehending': 10,
#  'readiness': 24,
#  'delights': 23,
#  'wondered': 46,
#  'receives': 16,
#  'perceive': 89,
#  'unfortunate': 55,
#  'mischief': 87,
#  'expectations': 16,
#  'obscurity': 9,
#  'disgrace': 27,
#  'involved': 34,
#  'revealed': 74,
#  'encourage': 17,
#  'desperate': 58,
#  'application': 25,
#  'sincerity': 35,
#  'habitual': 9,
#  'opposite': 99,
#  'unpleasant': 36,
#  'thousand': 752,
#  'abruptly': 63,
#  'provoking': 23,
#  'exceedingly': 111,
#  'adversary': 25,
#  'materially': 15,
#  'possibility': 41,
#  'prominent': 9,
#  'uneasiness': 23,
#  'pretensions': 11,
#  'attentive': 37,
#  'otherwise': 120,
#  'prudence': 28,
#  'originally': 22,
#  'conscious': 61,
#  'significantly': 8,
#  'forgiven': 66,
#  'proceedings': 12,
#  'justified': 73,
#  'remembered': 137,
#  'furnished': 34,
#  'improving': 13,
#  'chapters': 8,
#  'intention': 38,
#  'pleasanter': 8,
#  'imagination': 62,
#  'labouring': 10,
#  'comprehension': 12,
#  'literary': 9,
#  'collecting': 13,
#  'ornamented': 9,
#  'literature': 10,
#  'assisted': 21,
#  'invention': 15,
#  'recollect': 61,
#  'contribute': 11,
#  'intently': 22,
#  'recollections': 10,
#  'affliction': 100,
#  'security': 21,
#  'freshness': 17,
#  'addressed': 38,
#  'collection': 17,
#  'pondered': 10,
#  'puzzling': 16,
#  'confusion': 94,
#  'addresses': 8,
#  'convince': 38,
#  'observations': 17,
#  'eagerness': 53,
#  'syllable': 28,
#  'concluding': 24,
#  'congratulate': 17,
#  'alliance': 12,
#  'embraces': 17,
#  'acknowledgment': 10,
#  'strangest': 10,
#  'Shakespeare': 9,
#  'Michaelmas': 8,
#  'invitations': 13,
#  'preached': 68,
#  'provided': 58,
#  'twelvemonth': 20,
#  'declining': 20,
#  'exception': 22,
#  'committed': 108,
#  'submitted': 24,
#  'overpowered': 13,
#  'ridiculous': 27,
#  'distinctly': 31,
#  'explanations': 9,
#  'conclusion': 37,
#  'approach': 76,
#  'grandmama': 12,
#  'inconvenient': 12,
#  'necessity': 71,
#  'thankful': 19,
#  'promises': 34,
#  'accomplish': 34,
#  'submissive': 10,
#  'affected': 50,
#  'frightful': 27,
#  'whichever': 9,
#  'preparation': 38,
#  'discerned': 19,
#  'ostensible': 9,
#  'promised': 163,
#  'declined': 29,
#  'examined': 35,
#  'effusion': 8,
#  'honoured': 31,
#  'speeches': 16,
#  'charitable': 18,
#  'detached': 14,
#  'Vicarage': 12,
#  'irregular': 26,
#  'dwellings': 27,
#  'proprietor': 18,
#  'slackened': 8,
#  'observing': 47,
#  'curtains': 45,
#  'intimately': 9,
#  'contrive': 8,
#  'pretence': 23,
#  'housekeeper': 43,
#  'recollecting': 21,
#  'formidable': 16,
#  'relative': 20,
#  'unmarried': 8,
#  'contract': 8,
#  'contracted': 12,
#  'shilling': 36,
#  'sixpence': 25,
#  'resources': 13,
#  'occupations': 8,
#  'affections': 34,
#  'sensation': 28,
#  'grandmother': 40,
#  'compassionate': 13,
#  'distresses': 16,
#  'temptations': 14,
#  'romantic': 30,
#  'troubles': 33,
#  'sympathy': 32,
#  'intelligence': 50,
#  'sickness': 39,
#  'remaining': 59,
#  'impression': 69,
#  'trifling': 18,
#  'creatures': 107,
#  'slippery': 17,
#  'stopping': 43,
#  'wretchedness': 13,
#  'exertion': 44,
#  'wretched': 65,
#  'distressing': 13,
#  'ourselves': 137,
#  'sufferings': 29,
#  'accompany': 16,
#  'increase': 127,
#  'footpath': 8,
#  'alteration': 25,
#  'stooping': 20,
#  'overtaken': 8,
#  'obligation': 13,
#  'involuntarily': 21,
#  'experienced': 26,
#  'interests': 12,
#  'throwing': 50,
#  'acknowledged': 41,
#  'communicated': 24,
#  'incessant': 26,
#  'practicable': 11,
#  'successfully': 14,
#  'purposely': 12,
#  'allusions': 10,
#  'cautious': 26,
#  'advances': 14,
#  'believes': 11,
#  'ingenious': 12,
#  'measures': 61,
#  'anticipation': 10,
#  'henceforth': 74,
#  'exciting': 19,
#  'holidays': 12,
#  'coachman': 10,
#  'needless': 12,
#  'competent': 9,
#  'reaching': 39,
#  'dispersed': 21,
#  'respected': 12,
#  'maternal': 13,
#  'solicitude': 37,
#  'instantly': 121,
#  'attendance': 18,
#  'drinking': 72,
#  'restless': 42,
#  'tenderly': 12,
#  'inherited': 9,
#  'Wingfield': 10,
#  'benevolence': 15,
#  'profession': 48,
#  ...}

# %% [markdown]
# ### Exercise 1.4
# *Find the average number of words across the documents of the NLTK Gutenberg corpus.*

# %%
wordCount = []
for fileid in nltk.corpus.gutenberg.fileids():
    wordCount += [len(nltk.corpus.gutenberg.words(fileid))]
avg = sum(wordCount)/len(wordCount)
avg
# Out:
# 145645.16666666666

# %% [markdown]
# ### Exercise 1.5
# *Find the Gutenberg document that has the longest average word length.*

# %%
avgWordLen = {}
for fileid in nltk.corpus.gutenberg.fileids():
    chars = int()
    for word in nltk.corpus.gutenberg.words(fileid):
        chars += len(word)
    avgWordLen.update({fileid:(chars/len(nltk.corpus.gutenberg.words(fileid)))})
avgWordLen
# Out:
# {'austen-emma.txt': 3.755268231589122,
#  'austen-persuasion.txt': 3.8710311599148426,
#  'austen-sense.txt': 3.881371136350794,
#  'bible-kjv.txt': 3.4478209159613478,
#  'blake-poems.txt': 3.503471390950443,
#  'bryant-stories.txt': 3.500494933678887,
#  'burgess-busterbrown.txt': 3.5167431313610718,
#  'carroll-alice.txt': 3.401026092055116,
#  'chesterton-ball.txt': 3.824590704771331,
#  'chesterton-brown.txt': 3.790804410722378,
#  'chesterton-thursday.txt': 3.7742765087483567,
#  'edgeworth-parents.txt': 3.50881265338479,
#  'melville-moby_dick.txt': 3.830411128023649,
#  'milton-paradise.txt': 3.8873121611154144,
#  'shakespeare-caesar.txt': 3.4441218596368985,
#  'shakespeare-hamlet.txt': 3.4637312633832975,
#  'shakespeare-macbeth.txt': 3.4653414001728606,
#  'whitman-leaves.txt': 3.6962481356895203}

# %% [markdown]
# ### Exercise 1.6
# *Find the 10 most frequent bigrams in the entire Gutenberg corpus.*

# %%
# Out:
# [((',', 'and'), 41294),
#  (('of', 'the'), 18912),
#  (('in', 'the'), 9793),
#  (("'", 's'), 9781),
#  ((';', 'and'), 7559),
#  (('and', 'the'), 6432),
#  (('the', 'LORD'), 5964),
#  ((',', 'the'), 5957),
#  ((',', 'I'), 5677),
#  ((',', 'that'), 5352)]

# %% [markdown]
# ### Exercise 1.7
# *Find the most frequent bigram that begins with "Moby" in Herman Melville's "Moby Dick".*

# %%
# Out:
# [(('Moby', 'Dick'), 83), (('Moby', '-'), 1)]

# %% [markdown]
# # 2. Text Preprocessing with NLTK
# The following exercises will ask several questions about tokens, stems, and parts of speech.
#
# ### Exercise 2.1
# *What is the sentence with the largest number of tokens in Austen's "Emma"?*

# %%
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# The longest sentence is
# While he lived, it must be only an engagement;
# but she flattered herself, that if divested of the danger of
# drawing her away, it might become an increase of comfort to him.--
# How to do her best by Harriet, was of more difficult decision;--
# how to spare her from any unnecessary pain; how to make
# her any possible atonement; how to appear least her enemy?--
# On these subjects, her perplexity and distress were very great--
# and her mind had to pass again and again through every bitter
# reproach and sorrowful regret that had ever surrounded it.--
# She could only resolve at last, that she would still avoid a
# meeting with her, and communicate all that need be told by letter;
# that it would be inexpressibly desirable to have her removed just
# now for a time from Highbury, and--indulging in one scheme more--
# nearly resolve, that it might be practicable to get an invitation
# for her to Brunswick Square.--Isabella had been pleased with Harriet;
# and a few weeks spent in London must give her some amusement.--
# She did not think it in Harriet's nature to escape being benefited
# by novelty and variety, by the streets, the shops, and the children.--
# At any rate, it would be a proof of attention and kindness in herself,
# from whom every thing was due; a separation for the present; an averting
# of the evil day, when they must all be together again.
# The mumber of words of the longest sentence is 275

# %% [markdown]
# ### Exercise 2.2
# *What is the most frequent part of speech in Austen's "Emma"?*

# %%
# Out:
# [('NN', 19330), ('IN', 17880), ('PRP', 15619), ('RB', 12997), ('DT', 12743)]

# %% [markdown]
# ### Exercise 2.3
# *What is the number of distinct stems in Austen's "Emma"?*

# %%
# Out:
# Austen's Emma has 5394 distinct stems

# %% [markdown]
# ### Exercise 2.4
# *What is the most ambiguous stem in Austen's "Emma"? (meaning, which stem in Austen's "Emma" maps to the largest number of distinct tokens?)*

# %%
# Out:
# The most ambiguous stem is respect with words {'respectfully', 'respectably', 'respects', 'respected', 'respect', 'respectability', 'respectable', 'respective', 'respecting', 'respectful', 'Respect'}
